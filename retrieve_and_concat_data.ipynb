# %% [markdown]
# # Retrieve Data

# %% [markdown]
# This notebook explores and downloads a dataset that meets the following criteria:
# * `YEAR` = 2024
# * `MONTH` is between March and July

# %%
from sqlalchemy import create_engine
from pathlib import Path
import pandas as pd
import helpers as h
from pathlib import Path
import os
import importlib
import helpers as h
import duckdb
import geopandas as gpd
from shapely import wkt

# %% [markdown]
# Using `pgadmin`, I found that there are 21,946,235 rows that match the date range criteria.

# %% [markdown]
# Download the first 100,000 rows of the dataset slice:

# %%
@h.Timer()
def retrieve_data():
    """Downloads appropriate selection of data from PostgreSQL database"""

    with open('data/user.txt', 'r') as file:
        user = file.read().strip('\n')

    with open('data/pass.txt', 'r') as file:
        pw = file.read().strip('\n')

    with open('data/db_host.txt', 'r') as file:
        host = file.read().strip('\n')

    with open('data/db_port.txt', 'r') as file:
        port = file.read().strip('\n')

    with open('data/db_name.txt', 'r') as file:
        name = file.read().strip('\n')

    engine = create_engine(f'postgresql://{user}:{pw}@{host}:{port}/{name}')

    query = """SELECT * FROM blob WHERE "YEAR" = '2024' AND "MONTH" BETWEEN '03' AND '07' limit 100000;"""

    df = pd.read_sql(query, engine)

    parquet_path = Path('data/blob_data_100k.parquet')
    df.to_parquet(parquet_path, engine='pyarrow')

    print(f'Data saved to: {parquet_path}')

# %%
# run function
retrieve_data()
# Out:
# Data saved to: data/blob_data_100k.parquet
# Function `retrieve_data` executed in 654.5031 sec, CPU: 2.50%, Memory: 1362.84MB

# %%
# confirm count of created dataset

parquet_path = Path('data/blob_data_100k.parquet')

check = duckdb.sql(
        f"SELECT count(*) FROM read_parquet('{parquet_path}')"
    ).to_df()

check.head()
# Out:
#    count_star()
# 0        100000

# %% [markdown]
# All 100,000 rows were downloaded successfully.

# %%
# check how many rows of each month are included
parquet_path = Path('data/blob_data_100k.parquet')

check = duckdb.sql(
        f"""
        SELECT "MONTH", count(*) as ct 
        FROM read_parquet('{parquet_path}') 
        where "YEAR" = '2024'
        group by "MONTH"
        """).to_df()

check.head()
# Out:
#   MONTH     ct
# 0    06  96802
# 1    07   3198

# %% [markdown]
# Note that not all months in the window are included in the first 100,000 rows, only June and July.

# %%
# inspect data
parquet_path = Path('data/blob_data_100k.parquet')

df = duckdb.sql(f"""select * from read_parquet('{parquet_path}') limit 5;""").to_df()
df
# Out:
#                                     BLOB_ID  \
# 0  BID_a7258c95-7e44-424d-a227-1348f791ba39
# 1  BID_b433a935-c506-4937-9be8-9b63b87ca696
# 2  BID_d9fa48dd-5ee7-4258-9d56-264d38f2eecc
# 3  BID_44517c93-b035-42b5-90dd-de2e341aa1d8
# 4  BID_cd928abd-adbf-4481-bc2f-627c7e0e27f9
#
#                                          FULL_IMG_ID  \
# 0  FIID_58e9d2e6-11aa-4bc1-b1b0-951d312e72f5_2024...
# 1  FIID_58e9d2e6-11aa-4bc1-b1b0-951d312e72f5_2024...
# 2  FIID_87c905a3-ddd6-4a93-84cb-f07be70e1327_2024...
# 3  FIID_58e9d2e6-11aa-4bc1-b1b0-951d312e72f5_2024...
# 4  FIID_58e9d2e6-11aa-4bc1-b1b0-951d312e72f5_2024...
#
#                                            POINT  SIZE  \
# 0    POINT (-98.4602132804818 29.46763817191083)   452
# 1  POINT (-98.42449395672409 29.509311504753402)   935
# 2   POINT (-96.87599626765075 32.86770283696455)  4396
# 3  POINT (-98.42545971924973 29.455358060608745)   623
# 4  POINT (-98.43521898353451 29.502309820768644)   451
#
#                                  POLYGON_BOUNDRY_BOX  \
# 0  POLYGON ((-98.4602662037037 29.467706018518502...
# 1  POLYGON ((-98.42457175925924 29.50939120370369...
# 2  POLYGON ((-96.87620601851854 32.86782175925923...
# 3  POLYGON ((-98.4255162037037 29.455418981481465...
# 4  POLYGON ((-98.43526620370369 29.50235879629628...
#
#                                         BLOB_POLYGON       GEO_HASHES  \
# 0  POLYGON ((-98.4602662037037 29.467645833333318...          9v1zxkr
# 1  POLYGON ((-98.42457175925924 29.50937268518517...  9v4pb7c|9v4pbk1
# 2  POLYGON ((-96.87620601851854 32.86776157407404...  9vg4gx3|9vg4gx2
# 3  POLYGON ((-98.4255162037037 29.455418981481465...          9v4p860
# 4  POLYGON ((-98.43526620370369 29.50234953703702...          9v4pb49
#
#   CONSTRUCTION_STAGE           BUILDING_TYPE  \
# 0               ROOF                  NON-SF
# 1               ROOF  RESIDENTAL SF DETACHED
# 2               ROOF                  NON-SF
# 3               ROOF              BACKGROUND
# 4               ROOF  RESIDENTAL SF DETACHED
#
#                                 CS_MODEL_ID  ... IS_DUPLICATE  \
# 0  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...        False
# 1  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...        False
# 2  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...         True
# 3  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...        False
# 4  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...        False
#
#   IS_BLOB_ON_IMAGE_EDGE IS_VALID IS_IMPUTED IS_EXCLUDED  COUNTY  \
# 0                 False     True      False       False   BEXAR
# 1                 False     True      False       False   BEXAR
# 2                 False     True      False       False  DALLAS
# 3                 False     True      False       False   BEXAR
# 4                 False     True      False       False   BEXAR
#
#    IS_OVERLAPPING_FOOTPRINT  IS_OVERLAPPING_ROAD  \
# 0                      True                False
# 1                      True                False
# 2                      True                False
# 3                     False                False
# 4                     False                False
#
#                                  FOOTPRINT_ID  ROAD_DATA_ID
# 0  FP_ID_1a055cc6-21f7-416a-90a3-f8afd3e13b1c          None
# 1  FP_ID_0e97e0c6-451c-4a83-a304-22d6a698cb19          None
# 2  FP_ID_41e0c77e-db4b-4702-bae9-17f823ef2cd8          None
# 3                                        None          None
# 4                                        None          None
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   BLOB_ID                   5 non-null      object
#  1   FULL_IMG_ID               5 non-null      object
#  2   POINT                     5 non-null      object
#  3   SIZE                      5 non-null      int64
#  4   POLYGON_BOUNDRY_BOX       5 non-null      object
#  5   BLOB_POLYGON              5 non-null      object
#  6   GEO_HASHES                5 non-null      object
#  7   CONSTRUCTION_STAGE        5 non-null      object
#  8   BUILDING_TYPE             5 non-null      object
#  9   CS_MODEL_ID               5 non-null      object
#  10  BT_MODEL_ID               5 non-null      object
#  11  CITY                      5 non-null      object
#  12  STATE                     5 non-null      object
#  13  YEAR                      5 non-null      object
#  14  MONTH                     5 non-null      object
#  15  PREVIOUS_MONTH_BLOB_IDS   0 non-null      object
#  16  IS_DUPLICATE              5 non-null      bool
#  17  IS_BLOB_ON_IMAGE_EDGE     5 non-null      bool
#  18  IS_VALID                  5 non-null      bool
#  19  IS_IMPUTED                5 non-null      bool
#  20  IS_EXCLUDED               5 non-null      bool
#  21  COUNTY                    5 non-null      object
#  22  IS_OVERLAPPING_FOOTPRINT  5 non-null      bool
#  23  IS_OVERLAPPING_ROAD       5 non-null      bool
#  24  FOOTPRINT_ID              3 non-null      object
#  25  ROAD_DATA_ID              0 non-null      object
# dtypes: bool(7), int64(1), object(18)
# memory usage: 927.0+ bytes

# %% [markdown]
# Get schema of the downloaded dataset:

# %%
parquet_path = Path('data/blob_data_100k.parquet')
duckdb.sql(f"DESCRIBE SELECT * FROM read_parquet('{parquet_path}')").show()
# Out:
# ┌──────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │       column_name        │ column_type │  null   │   key   │ default │  extra  │
# │         varchar          │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├──────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ BLOB_ID                  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ FULL_IMG_ID              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ POINT                    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ SIZE                     │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ POLYGON_BOUNDRY_BOX      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ BLOB_POLYGON             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ GEO_HASHES               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ CONSTRUCTION_STAGE       │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ BUILDING_TYPE            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ CS_MODEL_ID              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │      ·                   │    ·        │  ·      │  ·      │  ·      │  ·      │
# │      ·                   │    ·        │  ·      │  ·      │  ·      │  ·      │
# │      ·                   │    ·        │  ·      │  ·      │  ·      │  ·      │
# │ IS_DUPLICATE             │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ IS_BLOB_ON_IMAGE_EDGE    │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ IS_VALID                 │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ IS_IMPUTED               │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ IS_EXCLUDED              │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ COUNTY                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ IS_OVERLAPPING_FOOTPRINT │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ IS_OVERLAPPING_ROAD      │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ FOOTPRINT_ID             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ ROAD_DATA_ID             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# ├──────────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┤
# │ 26 rows (20 shown)                                                   6 columns │
# └────────────────────────────────────────────────────────────────────────────────┘

# %%
print(f"This slice of data is about {100000/21946235 * 100:.3f}% of the total size of the dataset.")
# Out:
# This slice of data is about 0.456% of the total size of the dataset.

# %% [markdown]
# Create synthetic dataset to test our retrieve data function:

# %%
# Reload helpers if needed.
importlib.reload(h)

# Create a fake dataset with 10,000 rows.
num_rows = 1000
months = ['03', '04', '05', '06', '07']
data = {
    "BLOB_ID": [f"blob_{i}" for i in range(num_rows)],
    "YEAR": ['2024'] * num_rows,
    # Cycle through the months list.
    "MONTH": [months[i % len(months)] for i in range(num_rows)],
    "VALUE": [i for i in range(num_rows)],
    # Simulate CTID as an integer that increases sequentially.
    "ctid": [i for i in range(num_rows)]
}
fake_df = pd.DataFrame(data)

# Create a file-based SQLite database.
sqlite_db_path = "fake_blob.db"
engine = create_engine(f"sqlite:///{sqlite_db_path}")
# Save the fake DataFrame to a table named 'blob'.
fake_df.to_sql("blob", engine, if_exists="replace", index=False)

# Ensure the data directory exists.
os.makedirs("data", exist_ok=True)

# Remove any existing checkpoint file to start fresh.
checkpoint_path = Path("data/chunk_checkpoint.json")
if checkpoint_path.exists():
    checkpoint_path.unlink()

# Now run our retrieve_data function using the SQLite engine.
# In this test, we set chunk_size=2500 to produce 4 chunks.
h.retrieve_data(chunk_size=500, engine_url=f"sqlite:///{sqlite_db_path}")
# Out:
# Function `retrieve_data` executed in 0.0075 sec, CPU: 4.10%, Memory: 11.19MB

# %% [markdown]
# # Run function to download data

# %% [markdown]
# Now we will run the function on the actual dataset. The way the function is written, it can pick up where it left off by relying on checkpoint files.

# %%
# Reload helpers if needed
importlib.reload(h)

h.retrieve_data(chunk_size=100000, max_chunks=10, prefix='blob_20250307')
# Out:
# Starting chunk 7. Last CTID: (11010946,3)
# Function `retrieve_data` executed in 80.5807 sec, CPU: 5.30%, Memory: 188.38MB

# %% [markdown]
# We encountered an issue where there was no more room in the tmp folder on the database side, but we managed to download 6 chunks of data, or 600,000 rows.

# %% [markdown]
# Let's now inspect our downloaded chunks:

# %%
# test count(*) of created dataset

parquet_path = Path('archive/blob_20250307_chunk_1.parquet')

check = duckdb.sql(
        f"SELECT count(*) FROM read_parquet('{parquet_path}')"
    ).to_df()

check
# Out:
#    count_star()
# 0        100000

# %%
parquet_path = Path('archive/blob_20250307_chunk_1.parquet')

check = duckdb.sql(
        f"""
        SELECT "MONTH" ,count(*) 
        FROM read_parquet('{parquet_path}')
        group by "MONTH"
        order by "MONTH"
        """
    ).to_df()

check
# Out:
#   MONTH  count_star()
# 0    03           322
# 1    04             1
# 2    05            13
# 3    06         95895
# 4    07          3769

# %%
parquet_path = Path('archive/blob_20250307_chunk_1.parquet')

check = duckdb.sql(
        f"""
        SELECT * 
        FROM read_parquet('{parquet_path}')
        """
    ).to_df()

check.head(3)
# Out:
#                                     BLOB_ID  \
# 0  BID_4b0de362-432b-4169-880b-2502fe191e45
# 1  BID_8ae754b5-026d-4aac-9b9c-7b473bcf1f79
# 2  BID_ea519744-3092-4bb3-a340-19afe400056f
#
#                                          FULL_IMG_ID  \
# 0  FIID_eeca1e04-8ba1-43cb-931c-81c560491477_2024...
# 1  FIID_46cf3f0f-2345-41e0-8e50-fcf561da16c4_2024...
# 2  FIID_f7968076-35bc-42c8-b417-f88e8fafd619_2024...
#
#                                            POINT  SIZE  \
# 0  POINT (-96.57220292317847 32.777977159601775)   519
# 1  POINT (-95.33409120370364 29.674920974576246)  1180
# 2  POINT (-96.74267940156228 33.196998841454544)  1017
#
#                                  POLYGON_BOUNDRY_BOX  \
# 0  POLYGON ((-96.57224768518518 32.77805324074072...
# 1  POLYGON ((-95.33415972222215 29.67505787037034...
# 2  POLYGON ((-96.74277546296292 33.19707175925927...
#
#                                         BLOB_POLYGON GEO_HASHES  \
# 0  POLYGON ((-96.57224768518518 32.77797916666665...    9vg66rn
# 1  POLYGON ((-95.33415972222215 29.67503935185182...    9vk0yd5
# 2  POLYGON ((-96.74277546296292 33.19699305555556...    9vghye6
#
#   CONSTRUCTION_STAGE           BUILDING_TYPE  \
# 0               ROOF  RESIDENTAL SF DETACHED
# 1               ROOF  RESIDENTAL SF DETACHED
# 2               ROOF  RESIDENTAL SF DETACHED
#
#                                 CS_MODEL_ID  ... IS_BLOB_ON_IMAGE_EDGE  \
# 0  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...                 False
# 1  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...                 False
# 2  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...                 False
#
#   IS_VALID IS_IMPUTED IS_EXCLUDED  COUNTY IS_OVERLAPPING_FOOTPRINT  \
# 0     True      False       False  DALLAS                     True
# 1     True      False       False  HARRIS                     True
# 2     True      False       False  COLLIN                     True
#
#    IS_OVERLAPPING_ROAD                                FOOTPRINT_ID  \
# 0                False  FP_ID_36b25e18-56d6-482d-8f54-dac7c70c6687
# 1                False  FP_ID_c7fa7535-5ebb-4132-9814-e695c737a316
# 2                False  FP_ID_6f9bcbaf-4075-4ceb-aab1-ccdc562744e7
#
#    ROAD_DATA_ID      pgt_ctid
# 0          None      (1000,6)
# 1          None   (1000000,6)
# 2          None  (10000001,2)
#
# [3 rows x 27 columns]

# %% [markdown]
# # Concatenate Downloaded Data

# %%
# define data location
data_location = Path('archive')

# retrieve all relevant parquet files
data_files = list(Path(data_location).glob('blob_20250307_chunk_*.parquet'))

data_files
# Out:
# [PosixPath('archive/blob_20250307_chunk_3.parquet'),
#  PosixPath('archive/blob_20250307_chunk_2.parquet'),
#  PosixPath('archive/blob_20250307_chunk_1.parquet'),
#  PosixPath('archive/blob_20250307_chunk_4.parquet'),
#  PosixPath('archive/blob_20250307_chunk_5.parquet'),
#  PosixPath('archive/blob_20250307_chunk_6.parquet')]

# %% [markdown]
# Concatenate data:

# %%
df = duckdb.sql("select * from 'data/blob_20250307_chunk_*.parquet'").to_df()
df.head()
# Out:
#                                     BLOB_ID  \
# 0  BID_4b0de362-432b-4169-880b-2502fe191e45
# 1  BID_8ae754b5-026d-4aac-9b9c-7b473bcf1f79
# 2  BID_ea519744-3092-4bb3-a340-19afe400056f
# 3  BID_ea962ddc-c9ad-4a0a-905e-2012e0d6485d
# 4  BID_ea9a59f0-7f15-4371-ac86-096cf4eeaf3f
#
#                                          FULL_IMG_ID  \
# 0  FIID_eeca1e04-8ba1-43cb-931c-81c560491477_2024...
# 1  FIID_46cf3f0f-2345-41e0-8e50-fcf561da16c4_2024...
# 2  FIID_f7968076-35bc-42c8-b417-f88e8fafd619_2024...
# 3  FIID_a2ae6d14-612c-4123-bd66-636f6821c091_2024...
# 4  FIID_f7968076-35bc-42c8-b417-f88e8fafd619_2024...
#
#                                            POINT  SIZE  \
# 0  POINT (-96.57220292317847 32.777977159601775)   519
# 1  POINT (-95.33409120370364 29.674920974576246)  1180
# 2  POINT (-96.74267940156228 33.196998841454544)  1017
# 3   POINT (-96.72505400860906 33.16324660904856)   826
# 4   POINT (-96.7388098211761 33.202477229997186)  1310
#
#                                  POLYGON_BOUNDRY_BOX  \
# 0  POLYGON ((-96.57224768518518 32.77805324074072...
# 1  POLYGON ((-95.33415972222215 29.67505787037034...
# 2  POLYGON ((-96.74277546296292 33.19707175925927...
# 3  POLYGON ((-96.72512731481478 33.16331712962967...
# 4  POLYGON ((-96.73887731481477 33.20259027777779...
#
#                                         BLOB_POLYGON       GEO_HASHES  \
# 0  POLYGON ((-96.57224768518518 32.77797916666665...          9vg66rn
# 1  POLYGON ((-95.33415972222215 29.67503935185182...          9vk0yd5
# 2  POLYGON ((-96.74277546296292 33.19699305555556...          9vghye6
# 3  POLYGON ((-96.72512731481478 33.16324768518522...  9vghwvp|9vghwvn
# 4  POLYGON ((-96.73887731481477 33.20255787037038...  9vghysm|9vghysk
#
#   CONSTRUCTION_STAGE           BUILDING_TYPE  \
# 0               ROOF  RESIDENTAL SF DETACHED
# 1               ROOF  RESIDENTAL SF DETACHED
# 2               ROOF  RESIDENTAL SF DETACHED
# 3               ROOF  RESIDENTAL SF DETACHED
# 4               ROOF  RESIDENTAL SF DETACHED
#
#                                 CS_MODEL_ID  ... IS_BLOB_ON_IMAGE_EDGE  \
# 0  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...                 False
# 1  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...                 False
# 2  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...                 False
# 3  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...                 False
# 4  MID_6bf26a1d-f36e-4364-bc9d-d759d5c75d74  ...                 False
#
#   IS_VALID IS_IMPUTED IS_EXCLUDED  COUNTY IS_OVERLAPPING_FOOTPRINT  \
# 0     True      False       False  DALLAS                     True
# 1     True      False       False  HARRIS                     True
# 2     True      False       False  COLLIN                     True
# 3     True      False       False  COLLIN                     True
# 4     True      False       False  COLLIN                     True
#
#    IS_OVERLAPPING_ROAD                                FOOTPRINT_ID  \
# 0                False  FP_ID_36b25e18-56d6-482d-8f54-dac7c70c6687
# 1                False  FP_ID_c7fa7535-5ebb-4132-9814-e695c737a316
# 2                False  FP_ID_6f9bcbaf-4075-4ceb-aab1-ccdc562744e7
# 3                False  FP_ID_3d617f10-f756-462f-b098-00badc42438a
# 4                False  FP_ID_3aa44e93-ea83-4f15-b570-078dad879910
#
#    ROAD_DATA_ID      pgt_ctid
# 0          None      (1000,6)
# 1          None   (1000000,6)
# 2          None  (10000001,2)
# 3          None  (10000002,6)
# 4          None  (10000003,2)
#
# [5 rows x 27 columns]

# %% [markdown]
# Confirm shape of concatenated dataset:

# %%
df.shape
# Out:
# (600000, 27)

# %% [markdown]
# Save downloaded data to new parquet file:

# %%
concatenated_parquet = Path('data/blob_20250307.parquet')
df.to_parquet('data/blob_20250307.parquet')
print('Done.')
# Out:
# Done.

# %% [markdown]
# Save downloaded data to a geojson file to view in QGIS:

# %%
# save version of data to geojson to confirm in QGIS
blobs_geojson = Path('data/blob_20250307.geojson')

# convert the 'BLOB_POLYGON' column from WKT to geometry objects
df['geometry'] = df[
    'BLOB_POLYGON'].apply(lambda x: wkt.loads(x) if isinstance(x, str) else x)

# create a GeoDataFrame, specifying the geometry column and CRS
gdf = gpd.GeoDataFrame(df, geometry='geometry', crs="EPSG:4326")

# write GeoDataFrame to GeoJSON file
if not blobs_geojson.is_file():
    gdf.to_file('data/blob_20250307.geojson', driver='GeoJSON')

print('GeoJSON file saved successfully.')
# Out:
# GeoJSON file saved successfully.
